// %%
let catalog=
[{name:"land",_children:
    [{name:"mammals",_children:
        [
        {name:"dog",_children:[]},
        {name:"cat",_children:[]}
        ]
    },
     {name:"reptiles",_children:
        [
        {name:"snake",_children:[]},
        {name:"cat",_children:[]}
        ]
    }]
     
},
{name:"sea",_children:
    [{name:"fish",_children:
        [
        {name:"barramundi",_children:[]},
        {name:"perch",_children:[]}
        ]
    },
     {name:"crustaceans",_children:
        [
        {name:"lobster",_children:[]},
        {name:"crab",_children:[]}
        ]
    }]
},

 {name:"air",_children:
    [{name:"birds",_children:
        [
        {name:"parrot",_children:[]},
        {name:"eagle",_children:[]}
        ]
    },
     {name:"bats",_children:
        [
        {name:"vampire",_children:[]},
        {name:"fruit",_children:[]}
        ]
    }]}




 
]

// %%
console.log(JSON.stringify(catalog,null,2))
// Out:
// [
//   {
//     "name": "land",
//     "_children": [
//       {
//         "name": "mammals",
//         "_children": [
//           {
//             "name": "dog",
//             "_children": []
//           },
//           {
//             "name": "cat",
//             "_children": []
//           }
//         ]
//       },
//       {
//         "name": "reptiles",
//         "_children": [
//           {
//             "name": "snake",
//             "_children": []
//           },
//           {
//             "name": "cat",
//             "_children": []
//           }
//         ]
//       }
//     ]
//   },
//   {
//     "name": "sea",
//     "_children": [
//       {
//         "name": "fish",
//         "_children": [
//           {
//             "name": "barramundi",
//             "_children": []
//           },
//           {
//             "name": "perch",
//             "_children": []
//           }
//         ]
//       },
//       {
// ...
